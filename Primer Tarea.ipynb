# %% [markdown]
# # Mineria de Datos
#
# ## Tarea 1
#
# ### 1. Creación ambiente en anaconda

# %% [markdown]
# ![1.png](attachment:5aa1780b-2773-4879-b75e-bb127ee47415.png)

# %% [markdown]
# ### 2. Instalacion de JupyterLab y Python

# %% [markdown]
# ![2.png](attachment:c6687033-0292-4a6c-8759-eb9ca84659f6.png)

# %% [markdown]
# ### 3. Instalación Scikit Learn

# %% [markdown]
# ![3.png](attachment:7d1d9ef3-8ff8-415a-86ad-9e16b70768f4.png)

# %% [markdown]
# ### 4. Látex

# %% [markdown]
# Tenemos la función de seno escrita con Látex $$ y=\sin(x)$$

# %% [markdown]
# ### 5. Video

# %% [markdown]
# EL link a un canal y un video muy útil para empezar en la ciencia de datos (https://www.youtube.com/watch?v=CjQ4NcU1NKg).
#
# El link para encontrar imagenes del mapa de Colombia (https://www.pngwing.com/es/search?q=mapa+de+colombia)

# %% [markdown]
# <h2> Tenemos un título con HTML </h2>
